# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**
#
# Understanding the dataset to explore how the data is present in the database and if there is a need of creating some aggregated tables that can help with:
#
#     *Vendor selection for profitability
#     *Product pricing Optimization

# %%
from sqlalchemy import create_engine
import pandas as pd

# Replace @ with %40 in password
engine = create_engine("mysql+pymysql://root:Sanjana%401611@localhost/inventorydb")

# Now use engine with pandas
tables = pd.read_sql("SHOW TABLES;", con=engine)
print(tables)
# Out:
#   Tables_in_inventorydb
# 0      begin_inventory1
# 1        end_inventory1
# 2      purchase_prices1
# 3            purchases1
# 4                sales1
# 5       vendor_invoice1

# %%
for table in tables['Tables_in_inventorydb']:
    print('-'*50, f'{table}','-'*50)
    print('count of records:', pd.read_sql(f"select count(*) as count from {table}",con=engine)['count'].values[0])
    display(pd.read_sql(f"select * from {table} limit 1000 ", con=engine))
# Out:
# -------------------------------------------------- begin_inventory1 --------------------------------------------------
# count of records: 1466
#              InventoryId  Store          City  Brand  \
# 0      1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1      1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2      1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3      1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4      1_HARDERSFIELD_72      1  HARDERSFIELD     72
# ..                   ...    ...           ...    ...
# 995  1_HARDERSFIELD_4152      1  HARDERSFIELD   4152
# 996  1_HARDERSFIELD_4153      1  HARDERSFIELD   4153
# 997  1_HARDERSFIELD_4157      1  HARDERSFIELD   4157
# 998  1_HARDERSFIELD_4160      1  HARDERSFIELD   4160
# 999  1_HARDERSFIELD_4174      1  HARDERSFIELD   4174
#
#                       Description   Size  onHand  Price   startDate
# 0     Gekkeikan Black & Gold Sake  750mL       8  12.99  01/01/2024
# 1          Canadian Club 1858 VAP  750mL       7  10.99  01/01/2024
# 2        Herradura Silver Tequila  750mL       6  36.99  01/01/2024
# 3      Herradura Reposado Tequila  750mL       3  38.99  01/01/2024
# 4            No. 3 London Dry Gin  750mL       6  34.99  01/01/2024
# ..                            ...    ...     ...    ...         ...
# 995                   Jenkins Rum  750mL       0   4.99  01/01/2024
# 996                   Jenkins Rum  1.75L      20  11.99  01/01/2024
# 997    Smirnoff Green Apple Vodka   50mL      85   0.99  01/01/2024
# 998  Bacardi Gran Reserva Maestro  750mL       1  19.99  01/01/2024
# 999       Kraken Black Spiced Rum  1.75L      21  29.99  01/01/2024
#
# [1000 rows x 9 columns]
# -------------------------------------------------- end_inventory1 --------------------------------------------------
# count of records: 2210
#              InventoryId  Store          City  Brand  \
# 0      1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1      1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 2      1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 3      1_HARDERSFIELD_72      1  HARDERSFIELD     72
# 4      1_HARDERSFIELD_75      1  HARDERSFIELD     75
# ..                   ...    ...           ...    ...
# 995  1_HARDERSFIELD_4054      1  HARDERSFIELD   4054
# 996  1_HARDERSFIELD_4062      1  HARDERSFIELD   4062
# 997  1_HARDERSFIELD_4064      1  HARDERSFIELD   4064
# 998  1_HARDERSFIELD_4066      1  HARDERSFIELD   4066
# 999  1_HARDERSFIELD_4075      1  HARDERSFIELD   4075
#
#                      Description        Size  onHand  Price     endDate
# 0    Gekkeikan Black & Gold Sake       750mL      11  12.99  31/12/2024
# 1       Herradura Silver Tequila       750mL       7  36.99  31/12/2024
# 2     Herradura Reposado Tequila       750mL       7  38.99  31/12/2024
# 3           No. 3 London Dry Gin       750mL       4  34.99  31/12/2024
# 4      Three Olives Tomato Vodka       750mL       7  14.99  31/12/2024
# ..                           ...         ...     ...    ...         ...
# 995       Patron XO Cafe Liqueur       375mL      11  12.99  31/12/2024
# 996   Goslings Dark'N Stormy RTD  250mL 4 Pk       9   8.99  31/12/2024
# 997      Calico Jack Pin/Coc Rum       1.75L      18  12.99  31/12/2024
# 998  Bacardi Oakheart Spiced Rum       1.75L      32  19.99  31/12/2024
# 999     Bacardi Pineapple Fusion       1.75L       3  19.99  31/12/2024
#
# [1000 rows x 9 columns]
# -------------------------------------------------- purchase_prices1 --------------------------------------------------
# count of records: 1247
#      Brand                  Description  Price    Size  Volume  \
# 0       58  Gekkeikan Black & Gold Sake  12.99   750mL     750
# 1       62     Herradura Silver Tequila  36.99   750mL     750
# 2       63   Herradura Reposado Tequila  38.99   750mL     750
# 3       72         No. 3 London Dry Gin  34.99   750mL     750
# 4       75    Three Olives Tomato Vodka  14.99   750mL     750
# ..     ...                          ...    ...     ...     ...
# 995   4264  Capt Morgan Spiced Rum Trav  16.99   750mL     750
# 996   4265       Capt Morgan Spiced Rum  10.99   375mL     375
# 997   4267            Bacardi Limon Rum  19.99  1750mL    1750
# 998   4268    Capt Morgan Private Stock  22.99   750mL     750
# 999   4269       Calico Jack Spiced Rum  11.99  1750mL    1750
#
#      Classification  PurchasePrice  VendorNumber                   VendorName  \
# 0                 1           9.28          8320  SHAW ROSS INT L IMP LTD
# 1                 1          28.67          1128  BROWN-FORMAN CORP
# 2                 1          30.46          1128  BROWN-FORMAN CORP
# 3                 1          26.11          9165  ULTRA BEVERAGE COMPANY LLP
# 4                 1          10.94          7245  PROXIMO SPIRITS INC.
# ..              ...            ...           ...                          ...
# 995               1          11.53          3960  DIAGEO NORTH AMERICA INC
# 996               1           8.26          3960  DIAGEO NORTH AMERICA INC
# 997               1          15.62           480  BACARDI USA INC
# 998               1          18.25          3960  DIAGEO NORTH AMERICA INC
# 999               1           9.22         12546  JIM BEAM BRANDS COMPANY
#
#     MyUnknownColumn MyUnknownColumn_[0]
# 0
# 1
# 2
# 3
# 4
# ..              ...                 ...
# 995
# 996
# 997
# 998
# 999
#
# [1000 rows x 11 columns]
# -------------------------------------------------- purchases1 --------------------------------------------------
# count of records: 1324
#                InventoryId  Store  Brand                   Description   Size  \
# 0        69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1         30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2        34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3      1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4        76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
# ..                     ...    ...    ...                           ...    ...
# 995  47_PELLA'S WISH_29996     47  29996        Wild Horse CC Cab Svgn  750mL
# 996      30_CULCHETH_27808     30  27808     Blackstone Chard Monterey  750mL
# 997      52_GRAYCOTT_40098     52  40098          Black Box Merlot Cal     3L
# 998      15_WANBORNE_14818     15  14818       Simi Pnt Nr Sonoma Cnty  750mL
# 999    67_EANVERNESS_38546     67  38546       Mark West Pnt Nr Sonoma  750mL
#
#      VendorNumber                   VendorName  PONumber      PODate  \
# 0             105  ALTAMAR BRANDS LLC               8124  21/12/2023
# 1            4466  AMERICAN VINTAGE BEVERAGE        8137  22/12/2023
# 2            4466  AMERICAN VINTAGE BEVERAGE        8137  22/12/2023
# 3            4466  AMERICAN VINTAGE BEVERAGE        8137  22/12/2023
# 4             388  ATLANTIC IMPORTING COMPANY       8169  24/12/2023
# ..            ...                          ...       ...         ...
# 995          1392  CONSTELLATION BRANDS INC         8108  20/12/2023
# 996          1392  CONSTELLATION BRANDS INC         8108  20/12/2023
# 997          1392  CONSTELLATION BRANDS INC         8108  20/12/2023
# 998          1392  CONSTELLATION BRANDS INC         8108  20/12/2023
# 999          1392  CONSTELLATION BRANDS INC         8108  20/12/2023
#
#     ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# 0      02/01/2024  04/01/2024  16/02/2024          35.71         6   214.26
# 1      01/01/2024  07/01/2024  21/02/2024           9.35         4    37.40
# 2      02/01/2024  07/01/2024  21/02/2024           9.41         5    47.05
# 3      01/01/2024  07/01/2024  21/02/2024           9.35         6    56.10
# 4      02/01/2024  09/01/2024  16/02/2024          21.32         5   106.60
# ..            ...         ...         ...            ...       ...      ...
# 995    02/01/2024  11/01/2024  10/02/2024          10.12        12   121.44
# 996    01/01/2024  11/01/2024  10/02/2024           4.54        12    54.48
# 997    02/01/2024  11/01/2024  10/02/2024          10.38         6    62.28
# 998    01/01/2024  11/01/2024  10/02/2024          10.73        12   128.76
# 999    02/01/2024  11/01/2024  10/02/2024           5.06         2    10.12
#
#      Classification
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 995               2
# 996               2
# 997               2
# 998               2
# 999               2
#
# [1000 rows x 16 columns]
# -------------------------------------------------- sales1 --------------------------------------------------
# count of records: 1370
#              InventoryId  Store  Brand                 Description  \
# 0    1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 1    1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 2    1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 3    1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 4    1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack
# ..                   ...    ...    ...                         ...
# 995  1_HARDERSFIELD_1348      1   1348          Knob Creek Bourbon
# 996  1_HARDERSFIELD_1348      1   1348          Knob Creek Bourbon
# 997  1_HARDERSFIELD_1348      1   1348          Knob Creek Bourbon
# 998  1_HARDERSFIELD_1348      1   1348          Knob Creek Bourbon
# 999  1_HARDERSFIELD_1348      1   1348          Knob Creek Bourbon
#
#            Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0         750mL              1         16.49       16.49  01/01/2024     750
# 1         750mL              2         32.98       16.49  02/01/2024     750
# 2         750mL              1         16.49       16.49  03/01/2024     750
# 3         750mL              1         14.49       14.49  08/01/2024     750
# 4    375mL 2 Pk              2         69.98       34.99  09/01/2024     375
# ..          ...            ...           ...         ...         ...     ...
# 995       375mL              1         15.99       15.99  10/01/2024     375
# 996       375mL              1         15.99       15.99  11/01/2024     375
# 997       375mL              1         15.99       15.99  12/01/2024     375
# 998       375mL              1         15.99       15.99  13/01/2024     375
# 999       375mL              1         15.99       15.99  14/01/2024     375
#
#      Classification  ExciseTax  VendorNo                   VendorName  \
# 0                 1       0.79     12546  JIM BEAM BRANDS COMPANY
# 1                 1       1.57     12546  JIM BEAM BRANDS COMPANY
# 2                 1       0.79     12546  JIM BEAM BRANDS COMPANY
# 3                 1       0.79     12546  JIM BEAM BRANDS COMPANY
# 4                 1       0.79     12546  JIM BEAM BRANDS COMPANY
# ..              ...        ...       ...                          ...
# 995               1       0.39     12546  JIM BEAM BRANDS COMPANY
# 996               1       0.39     12546  JIM BEAM BRANDS COMPANY
# 997               1       0.39     12546  JIM BEAM BRANDS COMPANY
# 998               1       0.39     12546  JIM BEAM BRANDS COMPANY
# 999               1       0.39     12546  JIM BEAM BRANDS COMPANY
#
#     MyUnknownColumn MyUnknownColumn_[0]
# 0
# 1
# 2
# 3
# 4
# ..              ...                 ...
# 995
# 996
# 997
# 998
# 999
#
# [1000 rows x 16 columns]
# -------------------------------------------------- vendor_invoice1 --------------------------------------------------
# count of records: 1190
#      VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0             105  ALTAMAR BRANDS LLC           04/01/2024      8124
# 1            4466  AMERICAN VINTAGE BEVERAGE    07/01/2024      8137
# 2             388  ATLANTIC IMPORTING COMPANY   09/01/2024      8169
# 3             480  BACARDI USA INC              12/01/2024      8106
# 4             516  BANFI PRODUCTS CORP          07/01/2024      8170
# ..            ...                          ...         ...       ...
# 995          4466  AMERICAN VINTAGE BEVERAGE    16/03/2024      9180
# 996           388  ATLANTIC IMPORTING COMPANY   22/03/2024      9112
# 997           480  BACARDI USA INC              17/03/2024      9113
# 998           516  BANFI PRODUCTS CORP          14/03/2024      9132
# 999          2396  BLACK PRINCE DISTILLERY INC  19/03/2024      9162
#
#          PODate     PayDate  Quantity    Dollars  Freight Approval
# 0    21/12/2023  16/02/2024         6     214.26     3.47
# 1    22/12/2023  21/02/2024        15     140.55     8.57
# 2    24/12/2023  16/02/2024         5     106.60     4.61
# 3    20/12/2023  05/02/2024     10100  137483.78  2935.20
# 4    24/12/2023  12/02/2024      1935   15527.25   429.20
# ..          ...         ...       ...        ...      ...      ...
# 995  03/03/2024  19/04/2024       211    1979.33     9.50
# 996  28/02/2024  23/04/2024        36     812.60     4.31
# 997  28/02/2024  01/05/2024     12843  145436.94   741.73
# 998  29/02/2024  21/04/2024      3027   21072.23   109.58
# 999  02/03/2024  16/04/2024        18     113.34     0.51
#
# [1000 rows x 10 columns]

# %%
purchases1 = pd.read_sql_query("select * from purchases1 where VendorNumber = 4466", con=engine)
purchases1
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0          4466  AMERICAN VINTAGE BEVERAGE        8137  22/12/2023
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  22/12/2023
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  22/12/2023
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# 0    01/01/2024  07/01/2024  21/02/2024           9.35         4    37.40
# 1    02/01/2024  07/01/2024  21/02/2024           9.41         5    47.05
# 2    01/01/2024  07/01/2024  21/02/2024           9.35         6    56.10
#
#    Classification
# 0               1
# 1               1
# 2               1

# %%
purchase_prices1 = pd.read_sql_query("select * from purchase_prices1 where VendorNumber = 4466", con=engine)
purchase_prices1
# Out:
#    Brand                   Description  Price    Size  Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL    1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL    1750               1
#
#    PurchasePrice  VendorNumber                   VendorName MyUnknownColumn  \
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
#
#   MyUnknownColumn_[0]
# 0
# 1

# %%
vendor_invoice1 = pd.read_sql_query("select * from vendor_invoice1 where VendorNumber = 4466", con=engine)
vendor_invoice1
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    07/01/2024      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    19/01/2024      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    18/01/2024      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    27/01/2024      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    04/02/2024      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    09/02/2024      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    17/02/2024      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    01/03/2024      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    07/03/2024      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    12/03/2024      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    16/03/2024      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    23/03/2024      9244
#
#         PODate     PayDate  Quantity  Dollars  Freight Approval
# 0   22/12/2023  21/02/2024        15   140.55     8.57
# 1   27/12/2023  26/02/2024       335  3142.33    16.97
# 2   03/01/2024  18/02/2024        41   383.35     1.99
# 3   14/01/2024  11/03/2024        72   673.20     3.30
# 4   19/01/2024  15/03/2024        79   740.21     3.48
# 5   24/01/2024  15/03/2024       347  3261.37    17.61
# 6   05/02/2024  02/04/2024        72   675.36     3.17
# 7   12/02/2024  28/03/2024       117  1096.05     5.15
# 8   19/02/2024  02/04/2024       129  1209.27     5.44
# 9   22/02/2024  16/04/2024       147  1377.87     6.61
# 10  03/03/2024  19/04/2024       211  1979.33     9.50
# 11  08/03/2024  21/04/2024       161  1510.69     6.95

# %%
sales1 = pd.read_sql_query("select * from sales1 where VendorNo = 12546", con=engine)
sales1
# Out:
#              InventoryId  Store  Brand                 Description  \
# 0    1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 1    1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 2    1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 3    1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 4    1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack
# ..                   ...    ...    ...                         ...
# 273  1_HARDERSFIELD_1396      1   1396                    Old Crow
# 274  1_HARDERSFIELD_1396      1   1396                    Old Crow
# 275  1_HARDERSFIELD_1396      1   1396                    Old Crow
# 276  1_HARDERSFIELD_1396      1   1396                    Old Crow
# 277  1_HARDERSFIELD_1396      1   1396                    Old Crow
#
#            Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0         750mL              1         16.49       16.49  01/01/2024     750
# 1         750mL              2         32.98       16.49  02/01/2024     750
# 2         750mL              1         16.49       16.49  03/01/2024     750
# 3         750mL              1         14.49       14.49  08/01/2024     750
# 4    375mL 2 Pk              2         69.98       34.99  09/01/2024     375
# ..          ...            ...           ...         ...         ...     ...
# 273       1.75L              1         15.99       15.99  16/01/2024    1750
# 274       1.75L              3         47.97       15.99  17/01/2024    1750
# 275       1.75L              1         15.99       15.99  18/01/2024    1750
# 276       1.75L              1         15.99       15.99  20/01/2024    1750
# 277       1.75L              1         15.99       15.99  27/01/2024    1750
#
#      Classification  ExciseTax  VendorNo                   VendorName  \
# 0                 1       0.79     12546  JIM BEAM BRANDS COMPANY
# 1                 1       1.57     12546  JIM BEAM BRANDS COMPANY
# 2                 1       0.79     12546  JIM BEAM BRANDS COMPANY
# 3                 1       0.79     12546  JIM BEAM BRANDS COMPANY
# 4                 1       0.79     12546  JIM BEAM BRANDS COMPANY
# ..              ...        ...       ...                          ...
# 273               1       1.84     12546  JIM BEAM BRANDS COMPANY
# 274               1       5.51     12546  JIM BEAM BRANDS COMPANY
# 275               1       1.84     12546  JIM BEAM BRANDS COMPANY
# 276               1       1.84     12546  JIM BEAM BRANDS COMPANY
# 277               1       1.84     12546  JIM BEAM BRANDS COMPANY
#
#     MyUnknownColumn MyUnknownColumn_[0]
# 0
# 1
# 2
# 3
# 4
# ..              ...                 ...
# 273
# 274
# 275
# 276
# 277
#
# [278 rows x 16 columns]

# %%
purchases1.groupby(['Brand', 'PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity  Dollars
# Brand PurchasePrice
# 5215  9.41                  5    47.05
# 5255  9.35                 10    93.50

# %%
purchase_prices1
# Out:
#    Brand                   Description  Price    Size  Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL    1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL    1750               1
#
#    PurchasePrice  VendorNumber                   VendorName MyUnknownColumn  \
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
#
#   MyUnknownColumn_[0]
# 0
# 1

# %%
vendor_invoice1
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    07/01/2024      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    19/01/2024      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    18/01/2024      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    27/01/2024      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    04/02/2024      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    09/02/2024      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    17/02/2024      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    01/03/2024      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    07/03/2024      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    12/03/2024      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    16/03/2024      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    23/03/2024      9244
#
#         PODate     PayDate  Quantity  Dollars  Freight Approval
# 0   22/12/2023  21/02/2024        15   140.55     8.57
# 1   27/12/2023  26/02/2024       335  3142.33    16.97
# 2   03/01/2024  18/02/2024        41   383.35     1.99
# 3   14/01/2024  11/03/2024        72   673.20     3.30
# 4   19/01/2024  15/03/2024        79   740.21     3.48
# 5   24/01/2024  15/03/2024       347  3261.37    17.61
# 6   05/02/2024  02/04/2024        72   675.36     3.17
# 7   12/02/2024  28/03/2024       117  1096.05     5.15
# 8   19/02/2024  02/04/2024       129  1209.27     5.44
# 9   22/02/2024  16/04/2024       147  1377.87     6.61
# 10  03/03/2024  19/04/2024       211  1979.33     9.50
# 11  08/03/2024  21/04/2024       161  1510.69     6.95

# %%
vendor_invoice1.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
vendor_invoice1.shape
# Out:
# (12, 10)

# %%
purchases1
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0          4466  AMERICAN VINTAGE BEVERAGE        8137  22/12/2023
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  22/12/2023
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  22/12/2023
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# 0    01/01/2024  07/01/2024  21/02/2024           9.35         4    37.40
# 1    02/01/2024  07/01/2024  21/02/2024           9.41         5    47.05
# 2    01/01/2024  07/01/2024  21/02/2024           9.35         6    56.10
#
#    Classification
# 0               1
# 1               1
# 2               1

# %%
sales1.groupby('Brand')[['SalesDollars', 'SalesPrice', 'SalesQuantity']].sum()
# Out:
#        SalesDollars  SalesPrice  SalesQuantity
# Brand
# 1004          80.45       63.96              5
# 1005         174.95      139.96              5
# 1006           3.99        3.99              1
# 1012          34.99       34.99              1
# 1035          43.96       32.97              4
# 1168         179.91       99.95              9
# 1239         152.97      152.97              3
# 1258         137.94      137.94              6
# 1261          26.73        4.95             27
# 1273          63.98       63.98              2
# 1278         209.94      174.95              6
# 1309          59.99       59.99              1
# 1340          35.98       35.98              2
# 1345         350.91      233.94              9
# 1346         989.67      419.86             33
# 1347          79.98       79.98              2
# 1348         367.77      255.84             23
# 1355          59.33       20.94             17
# 1358         495.92      309.95              8
# 1359         335.88      279.90             12
# 1366          95.46       24.51             74
# 1373         303.79      187.87             21
# 1375         376.74      231.84             26
# 1376        2422.94      526.77            106
# 1378         550.42      218.27             58
# 1379         544.13      308.29             37
# 1382         205.95      205.95              5
# 1385        1160.57      539.80             43
# 1388          74.97       74.97              3
# 1389          23.92       14.95              8
# 1392          42.97       28.48              3
# 1394          82.45       82.45              5
# 1395         143.82       95.88             18
# 1396         319.80      159.90             20

# %%
* The purchases table contains actual purchase data, including the data of purchase, products (brands) purchased by vendors, the amount paid(in dollars) and the quantity purchased.
*The purchase price column is derived from the purchase_prices table, which provides product-wise actual and purchase prices. the combination of vendor and barnd is unique in this table
*

# %%
vendor_invoice1.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary = pd.read_sql_query("""
    SELECT VendorNumber,
           SUM(Freight) AS FreightCost
    FROM vendor_invoice1
    GROUP BY VendorNumber
""", con=engine)

# %%
freight_summary
# Out:
#      VendorNumber  FreightCost
# 0             105        11.45
# 1            4466        88.74
# 2             388        72.05
# 3             480     13247.84
# 4             516      1834.51
# ..            ...          ...
# 110          6280         0.11
# 111          3951         2.69
# 112          6830         0.44
# 113             2         0.61
# 114         90026         0.36
#
# [115 rows x 2 columns]

# %%
pd.read_sql_query("""SELECT
    p.VendorNumber ,
    p.VendorName ,
    p.Brand , 
    p.PurchasePrice ,
    pp.Volume , 
    pp.Price AS ActualPrice ,
    SUM(p.Quantity) AS TotalPurchaseQuantity ,
    SUM(p.Dollars) AS TotalPurchaseDollars
    FROM purchases1 p
    JOIN purchase_prices1 pp
    ON p.Brand = pp.Brand
    GROUP BY 
    p.VendorNumber, 
    p.VendorName, 
    p.Brand,
    p.PurchasePrice ,
    pp.Volume , 
    pp.Price
    ORDER BY TotalPurchaseDollars""", con=engine )
# Out:
#      VendorNumber                   VendorName  Brand  PurchasePrice  Volume  \
# 0            4380  CHARLES JACQUIN ET CIE INC    5137           6.61     750
# 1             480  BACARDI USA INC               4025           1.37      50
# 2             480  BACARDI USA INC               4670           2.87     375
# 3             480  BACARDI USA INC               3847           2.81      50
# 4            4466  AMERICAN VINTAGE BEVERAGE     5215           9.41    1750
# ..            ...                          ...    ...            ...     ...
# 138           480  BACARDI USA INC               4221          12.94    1750
# 139           480  BACARDI USA INC               3344          14.49     750
# 140          1128  BROWN-FORMAN CORP             1233          26.27    1750
# 141           480  BACARDI USA INC               3858          17.77     750
# 142           480  BACARDI USA INC               4227          14.17    1750
#
#      ActualPrice  TotalPurchaseQuantity  TotalPurchaseDollars
# 0           9.99                    1.0                  6.61
# 1           1.79                   20.0                 27.40
# 2           4.49                   11.0                 31.57
# 3           3.79                   12.0                 33.72
# 4          12.99                    5.0                 47.05
# ..           ...                    ...                   ...
# 138        17.99                  734.0               9497.96
# 139        19.99                  672.0               9737.28
# 140        36.99                  401.0              10534.27
# 141        23.99                 1847.0              32821.19
# 142        17.99                 2418.0              34263.06
#
# [143 rows x 8 columns]

# %%
sales1.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName', 'MyUnknownColumn',
#        'MyUnknownColumn_[0]'],
#       dtype='object')

# %%
pd.read_sql_query("""SELECT
    VendorNo,
    Brand,
    SUM(SalesDollars) AS TotalSalesDollars,
    SUM(SalesPrice) AS TotalSalesPrice,
    SUM(SalesQuantity) AS TotalSalesQuantity,
    SUM(ExciseTax) AS TotalExciseTax
    FROM sales1
    GROUP BY VendorNo, Brand
    ORDER BY TotalSalesDollars""", con=engine)
# Out:
#      VendorNo  Brand  TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity  \
# 0       12546   1006               3.99             3.99                 1.0
# 1        3924   1029               9.99             9.99                 1.0
# 2        9165  12943               9.99             9.99                 1.0
# 3        6213   1364               9.99             9.99                 1.0
# 4        9819  11414              13.98            13.98                 2.0
# ..        ...    ...                ...              ...                 ...
# 228     12546   1385            1160.57           539.80                43.0
# 229      4425  11219            1316.12           327.78                88.0
# 230      1128   1232            1571.32           486.79                68.0
# 231     12546   1376            2422.94           526.77               106.0
# 232      1128   1233            3599.00           647.82               100.0
#
#      TotalExciseTax
# 0              0.05
# 1              0.79
# 2              0.11
# 3              0.79
# 4              0.22
# ..              ...
# 228           33.84
# 229            9.87
# 230           53.53
# 231          194.77
# 232          183.74
#
# [233 rows x 6 columns]

# %%
import time
import pandas as pd

def create_final_summary(con=engine):
    final_table = pd.read_sql_query("""SELECT
        pp.VendorNumber,
        pp.VendorName,
        pp.Brand,
        pp.Description,
        pp.Price AS ActualPrice,
        pp.PurchasePrice,
        pp.Volume ,
        SUM(s.SalesQuantity) AS TotalSalesQuantity,
        SUM(s.SalesDollars) AS TotalSalesDollars,
        SUM(s.SalesPrice) AS TotalSalesPrice,
        SUM(s.ExciseTax) AS TotalExciseTax,
        SUM(vi.Quantity) AS TotalPurchaseQuantity,
        SUM(vi.Dollars) AS TotalPurchaseDollars,
        SUM(vi.Freight) AS TotalFreightCost
        FROM purchase_prices1 pp
        JOIN sales1 s
        ON pp.VendorNumber = s.VendorNO
        AND pp.Brand = s.Brand
        JOIN vendor_invoice1 vi
        ON pp.VendorNumber = vi.VendorNumber
        GROUP BY pp.VendorNumber,
        pp.VendorName,
        pp.Brand,
        pp.Description,
        pp.Price,
        pp.PurchasePrice,
        pp.Volume 
        """, con=engine)

    return final_table

# %%
final_table
# Out:
#     VendorNumber                   VendorName  Brand  \
# 0           9552  M S WALKER INC                1094
# 1           8112  MOET HENNESSY USA INC         1133
# 2           8352  LUXCO INC                     1135
# 3           8112  MOET HENNESSY USA INC          115
# 4           8352  LUXCO INC                     1174
# 5           3924  HEAVEN HILL DISTILLERIES      1178
# 6           3924  HEAVEN HILL DISTILLERIES      1180
# 7           3924  HEAVEN HILL DISTILLERIES      1186
# 8           2555  DISARONNO INTERNATIONAL LLC   1212
# 9           1128  BROWN-FORMAN CORP             1220
# 10          9625  WESTERN SPIRITS BEVERAGE CO   1226
# 11          3664  WILLIAM GRANT & SONS INC      1228
# 12          1128  BROWN-FORMAN CORP             1231
# 13          1128  BROWN-FORMAN CORP             1232
# 14          1128  BROWN-FORMAN CORP             1233
# 15          1128  BROWN-FORMAN CORP             1237
# 16         17035  PERNOD RICARD USA             1238
# 17         12546  JIM BEAM BRANDS COMPANY       1239
# 18          1128  BROWN-FORMAN CORP             1244
# 19         12546  JIM BEAM BRANDS COMPANY       1258
# 20           480  BACARDI USA INC                126
# 21          1485  CASTLE BRANDS CORP.           1269
# 22          1485  CASTLE BRANDS CORP.           1271
# 23         12546  JIM BEAM BRANDS COMPANY       1273
# 24         12546  JIM BEAM BRANDS COMPANY       1278
# 25          8004  SAZERAC CO INC                1281
# 42              8677952.0          7.096746e+07         402427.68
# 43             12474556.0          1.020157e+08         578489.79
# 44             12474556.0          1.020157e+08         578489.79
# 45             11389812.0          9.314479e+07         528186.33
# 46              3827536.0          3.151884e+07         174957.48
# 47              2711860.0          2.217733e+07         125758.65
# 48             13396376.0          1.103159e+08         612351.18
# 49             10847440.0          8.870932e+07         503034.60
# 50               956884.0          7.879711e+06          43739.37
# 51              1627116.0          1.330640e+07          75455.19
# 52              2711860.0          2.217733e+07         125758.65
# 53              1084744.0          8.870932e+06          50303.46
# 54              2711860.0          2.217733e+07         125758.65
# 55              6508464.0          5.322559e+07         301820.76
# 56              5423720.0          4.435466e+07         251517.30

# %%
final_table.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# ActualPrice              float64
# PurchasePrice            float64
# Volume                     int64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# TotalPurchaseQuantity    float64
# TotalPurchaseDollars     float64
# TotalFreightCost         float64
# dtype: object

# %%
final_table.isnull().sum()
# Out:
# VendorNumber             0
# VendorName               0
# Brand                    0
# Description              0
# ActualPrice              0
# PurchasePrice            0
# Volume                   0
# TotalSalesQuantity       0
# TotalSalesDollars        0
# TotalSalesPrice          0
# TotalExciseTax           0
# TotalPurchaseQuantity    0
# TotalPurchaseDollars     0
# TotalFreightCost         0
# dtype: int64

# %%
final_table['VendorName'].unique()
# Out:
# array(['M S WALKER INC             ', 'MOET HENNESSY USA INC      ',
#        'LUXCO INC                  ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'BROWN-FORMAN CORP          ',
#        'WESTERN SPIRITS BEVERAGE CO', 'WILLIAM GRANT & SONS INC   ',
#        'PERNOD RICARD USA          ', 'JIM BEAM BRANDS COMPANY    ',
#        'BACARDI USA INC            ', 'CASTLE BRANDS CORP.        ',
#        'SAZERAC CO INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'MHW LTD                    ', 'STOLI GROUP,(USA) LLC      ',
#        'DIAGEO NORTH AMERICA INC   '], dtype=object)

# %%
final_table['Volume'].unique()
# Out:
# array([ 750,  100, 1000, 1750,  375,   50])

# %%
final_table['VendorName'] = final_table['VendorName'].str.strip()

# %%
final_table['Description'] = final_table['Description'].str.strip()

# %%
final_table['Description'].unique()
# Out:
# array(['Four Roses Single Barrel Brb', 'Glenmorangie Collection 4 Pk',
#        'Rebel Reserve Bourbon', 'Belvedere Vodka', 'Rebel Yell',
#        'Evan Williams Black Label B', 'Evan Williams Single Barrel',
#        'DiSaronna Amaretto Sour VAP', 'Woodford Reserve Bourbon',
#        'Lexington Bourbon', 'Glenfiddich Ancient RSV 18',
#        'Jack Daniels No 7 Black', 'Jack Daniels Single Barrel',
#        'The Glenlivet 12 Yr Single', "Booker's Bourbon",
#        'Jack Daniels Winter Jack', 'Jim Beam Black', 'Grey Goose Vodka',
#        'Jeffersons Bourbon', 'Jeffersons Reserve Bourbon',
#        'Jim Beam Choice', 'Benchmark Old #8 Bourbon', 'Small Batch 1792',
#        'Makers Mark Cask Strength', 'Early Times',
#        "Jim Beam Jacob's Ghost", 'Basil Hayden Bourbon',
#        'Knob Creek Bourbon', 'Bakers Bourbon', 'Knob Creek Rye',
#        'Bols Pumpkin Spice', 'Stoli Mini Bar 5/50mLs Pack',
#        'Red Stag by Jim Beam', 'Jim Beam Honey', 'Jim Beam',
#        'Jim Beam Traveler', 'Bulleit 95 Rye', 'Makers 46', 'Makers Mark',
#        'George Dickel No 8 Bourbon', 'Red Stag Hardcore Cider',
#        'Old Crow'], dtype=object)

# %%
final_table['VendorName'].unique()
# Out:
# array(['M S WALKER INC', 'MOET HENNESSY USA INC', 'LUXCO INC',
#        'HEAVEN HILL DISTILLERIES', 'DISARONNO INTERNATIONAL LLC',
#        'BROWN-FORMAN CORP', 'WESTERN SPIRITS BEVERAGE CO',
#        'WILLIAM GRANT & SONS INC', 'PERNOD RICARD USA',
#        'JIM BEAM BRANDS COMPANY', 'BACARDI USA INC',
#        'CASTLE BRANDS CORP.', 'SAZERAC CO INC',
#        'SAZERAC NORTH AMERICA INC.', 'MHW LTD', 'STOLI GROUP,(USA) LLC',
#        'DIAGEO NORTH AMERICA INC'], dtype=object)

# %%
final_table['GrossProfit'] = final_table['TotalSalesDollars'] - final_table['TotalPurchaseDollars']

# %%
final_table
# Out:
#     VendorNumber                   VendorName  Brand  \
# 0           9552               M S WALKER INC   1094
# 1           8112        MOET HENNESSY USA INC   1133
# 2           8352                    LUXCO INC   1135
# 3           8112        MOET HENNESSY USA INC    115
# 4           8352                    LUXCO INC   1174
# 5           3924     HEAVEN HILL DISTILLERIES   1178
# 6           3924     HEAVEN HILL DISTILLERIES   1180
# 7           3924     HEAVEN HILL DISTILLERIES   1186
# 8           2555  DISARONNO INTERNATIONAL LLC   1212
# 9           1128            BROWN-FORMAN CORP   1220
# 10          9625  WESTERN SPIRITS BEVERAGE CO   1226
# 11          3664     WILLIAM GRANT & SONS INC   1228
# 12          1128            BROWN-FORMAN CORP   1231
# 13          1128            BROWN-FORMAN CORP   1232
# 14          1128            BROWN-FORMAN CORP   1233
# 15          1128            BROWN-FORMAN CORP   1237
# 16         17035            PERNOD RICARD USA   1238
# 17         12546      JIM BEAM BRANDS COMPANY   1239
# 18          1128            BROWN-FORMAN CORP   1244
# 19         12546      JIM BEAM BRANDS COMPANY   1258
# 20           480              BACARDI USA INC    126
# 21          1485          CASTLE BRANDS CORP.   1269
# 22          1485          CASTLE BRANDS CORP.   1271
# 23         12546      JIM BEAM BRANDS COMPANY   1273
# 24         12546      JIM BEAM BRANDS COMPANY   1278
# 25          8004               SAZERAC CO INC   1281
# 26           660   SAZERAC NORTH AMERICA INC.   1282
# 27          1128            BROWN-FORMAN CORP   1295
# 28         12546      JIM BEAM BRANDS COMPANY   1309
# 29          1128            BROWN-FORMAN CORP   1323
# 30         12546      JIM BEAM BRANDS COMPANY   1340
# 31         12546      JIM BEAM BRANDS COMPANY   1345
# 32         12546      JIM BEAM BRANDS COMPANY   1346
# 51              1627116.0          1.330640e+07          75455.19
# 52              2711860.0          2.217733e+07         125758.65
# 53              1084744.0          8.870932e+06          50303.46
# 54              2711860.0          2.217733e+07         125758.65
# 55              6508464.0          5.322559e+07         301820.76
# 56              5423720.0          4.435466e+07         251517.30
#
#      GrossProfit
# 0  -1.948735e+06
# 1  -2.568193e+06
# 2  -4.326690e+06
# 3  -1.284078e+07
# 4  -1.441126e+06
# 5  -4.993324e+06
# 6  -7.711667e+06
# 7  -4.537657e+05
# 8  -8.549463e+05
# 9  -2.441710e+07
# 10 -6.077671e+04
# 11 -8.277257e+05
# 12 -3.907395e+07
# 13 -5.127205e+07
# 14 -4.392044e+07
# 15 -4.883648e+06
# 16 -1.595098e+07
# 17 -1.330456e+07
# 18 -4.884272e+06
# 19 -2.661114e+07
# 20 -2.860471e+07
# 21 -3.002382e+06
# 22 -5.455101e+05
# 23 -8.870165e+06
# 24 -2.217481e+07
# 25 -5.286243e+06
# 26 -1.870235e+06
# 27 -5.617259e+07
# 28 -4.434746e+06
# 29 -2.930530e+07
# 30 -8.870501e+06
# 31 -2.660859e+07
# 32 -6.208465e+07
# 33 -8.869973e+06
# 34 -7.096305e+07
# 35 -2.661209e+07
# 36 -2.217138e+07
# 37 -4.435063e+07
# 38 -3.380239e+05
# 39 -6.480473e+06
# 40 -8.427271e+07
# 41 -5.765742e+07
# 42 -7.096294e+07
# 43 -1.019866e+08
# 44 -1.020091e+08
# 45 -9.313826e+07
# 46 -3.151648e+07
# 47 -2.217486e+07
# 48 -1.103081e+08
# 49 -8.869540e+07
# 50 -7.879447e+06
# 51 -1.330550e+07
# 52 -2.217704e+07
# 53 -8.870417e+06
# 54 -2.217634e+07
# 55 -5.322387e+07
# 56 -4.435082e+07

# %%
final_table['GrossProfit'].min()
# Out:
# -110308103.26

# %% [raw]
# final_table['StockTurnover'] = final_table['TotalSalesQuantity'] / final_table['TotalPurchaseQuantity']

# %%
final_table
# Out:
#     VendorNumber                   VendorName  Brand  \
# 0           9552               M S WALKER INC   1094
# 1           8112        MOET HENNESSY USA INC   1133
# 2           8352                    LUXCO INC   1135
# 3           8112        MOET HENNESSY USA INC    115
# 4           8352                    LUXCO INC   1174
# 5           3924     HEAVEN HILL DISTILLERIES   1178
# 6           3924     HEAVEN HILL DISTILLERIES   1180
# 7           3924     HEAVEN HILL DISTILLERIES   1186
# 8           2555  DISARONNO INTERNATIONAL LLC   1212
# 9           1128            BROWN-FORMAN CORP   1220
# 10          9625  WESTERN SPIRITS BEVERAGE CO   1226
# 11          3664     WILLIAM GRANT & SONS INC   1228
# 12          1128            BROWN-FORMAN CORP   1231
# 13          1128            BROWN-FORMAN CORP   1232
# 14          1128            BROWN-FORMAN CORP   1233
# 15          1128            BROWN-FORMAN CORP   1237
# 16         17035            PERNOD RICARD USA   1238
# 17         12546      JIM BEAM BRANDS COMPANY   1239
# 18          1128            BROWN-FORMAN CORP   1244
# 19         12546      JIM BEAM BRANDS COMPANY   1258
# 20           480              BACARDI USA INC    126
# 21          1485          CASTLE BRANDS CORP.   1269
# 22          1485          CASTLE BRANDS CORP.   1271
# 23         12546      JIM BEAM BRANDS COMPANY   1273
# 24         12546      JIM BEAM BRANDS COMPANY   1278
# 25          8004               SAZERAC CO INC   1281
# 26           660   SAZERAC NORTH AMERICA INC.   1282
# 27          1128            BROWN-FORMAN CORP   1295
# 28         12546      JIM BEAM BRANDS COMPANY   1309
# 29          1128            BROWN-FORMAN CORP   1323
# 30         12546      JIM BEAM BRANDS COMPANY   1340
# 31         12546      JIM BEAM BRANDS COMPANY   1345
# 32         12546      JIM BEAM BRANDS COMPANY   1346
# 33         12546      JIM BEAM BRANDS COMPANY   1347
# 34         12546      JIM BEAM BRANDS COMPANY   1348
# 35         12546      JIM BEAM BRANDS COMPANY   1355
# 36         12546      JIM BEAM BRANDS COMPANY   1358
# 37         12546      JIM BEAM BRANDS COMPANY   1359
# 38          6213                      MHW LTD   1364
# 39          8664        STOLI GROUP,(USA) LLC   1365
# 40         12546      JIM BEAM BRANDS COMPANY   1366
# 41         12546      JIM BEAM BRANDS COMPANY   1373
# 42         12546      JIM BEAM BRANDS COMPANY   1375
# 43         12546      JIM BEAM BRANDS COMPANY   1376
# 44         12546      JIM BEAM BRANDS COMPANY   1378
# 45         12546      JIM BEAM BRANDS COMPANY   1379
# 46          3960     DIAGEO NORTH AMERICA INC   1380
# 47         12546      JIM BEAM BRANDS COMPANY   1382
# 48          3960     DIAGEO NORTH AMERICA INC   1384
# 49         12546      JIM BEAM BRANDS COMPANY   1385
# 50          3960     DIAGEO NORTH AMERICA INC   1386
# 51         12546      JIM BEAM BRANDS COMPANY   1388
# 52         12546      JIM BEAM BRANDS COMPANY   1389
# 53         12546      JIM BEAM BRANDS COMPANY   1392
# 54         12546      JIM BEAM BRANDS COMPANY   1394
# 55         12546      JIM BEAM BRANDS COMPANY   1395
# 56         12546      JIM BEAM BRANDS COMPANY   1396
#
#                      Description  ActualPrice  PurchasePrice  Volume  \
# 0   Four Roses Single Barrel Brb        40.99          29.92     750
# 1   Glenmorangie Collection 4 Pk        31.99          23.01     100
# 2          Rebel Reserve Bourbon        19.99          15.62     750
# 3                Belvedere Vodka        27.99          21.37    1000
# 4                     Rebel Yell        19.99          15.87    1750
# 5    Evan Williams Black Label B        10.99           7.83     750
# 6    Evan Williams Black Label B        16.99          13.07    1750
# 7    Evan Williams Single Barrel        24.99          17.98     750
# 8    DiSaronna Amaretto Sour VAP        21.99          14.38     750
# 9       Woodford Reserve Bourbon        29.99          21.89     750
# 10             Lexington Bourbon        29.99          19.99     750
# 11    Glenfiddich Ancient RSV 18        95.99          69.76     750
# 12       Jack Daniels No 7 Black        12.99           9.48     375
# 13       Jack Daniels No 7 Black        22.99          15.93     750
# 14       Jack Daniels No 7 Black        36.99          26.27    1750
# 15    Jack Daniels Single Barrel        44.99          33.83     750
# 16    The Glenlivet 12 Yr Single         4.99           3.56      50
# 17              Booker's Bourbon        49.99          39.99     750
# 18      Jack Daniels Winter Jack        17.99          12.79     750
# 32 -6.208465e+07 -5.227723e+05       0.000052            0.000191
# 33 -8.869973e+06 -9.241865e+05       0.000022            0.000108
# 34 -7.096305e+07 -1.607958e+06       0.000032            0.000062
# 35 -2.661209e+07 -3.737862e+06       0.000063            0.000027
# 36 -2.217138e+07 -3.725631e+05       0.000035            0.000268
# 37 -4.435063e+07 -1.100359e+06       0.000027            0.000091
# 38 -3.380239e+05 -2.819686e+05       0.000254            0.000355
# 39 -6.480473e+06 -4.827815e+05       0.000398            0.000207
# 40 -8.427271e+07 -7.356721e+06       0.000086            0.000014
# 41 -5.765742e+07 -1.581614e+06       0.000036            0.000063
# 42 -7.096294e+07 -1.569671e+06       0.000036            0.000064
# 43 -1.019866e+08 -3.507676e+05       0.000102            0.000285
# 44 -1.020091e+08 -1.544413e+06       0.000056            0.000065
# 45 -9.313826e+07 -1.426409e+06       0.000039            0.000070
# 46 -3.151648e+07 -1.333455e+06       0.000013            0.000075
# 47 -2.217486e+07 -8.972590e+05       0.000022            0.000111
# 48 -1.103081e+08 -1.406094e+06       0.000022            0.000071
# 49 -8.869540e+07 -6.368666e+05       0.000048            0.000157
# 50 -7.879447e+06 -2.985996e+06       0.000013            0.000033
# 51 -1.330550e+07 -1.478980e+06       0.000022            0.000068
# 52 -2.217704e+07 -7.726116e+06       0.000035            0.000013
# 53 -8.870417e+06 -1.720273e+06       0.000033            0.000058
# 54 -2.217634e+07 -2.241393e+06       0.000022            0.000045
# 55 -5.322387e+07 -3.083940e+06       0.000033            0.000032
# 56 -4.435082e+07 -1.155692e+06       0.000044            0.000087

# %%
final_table['ProfitMargin'] = (final_table['GrossProfit'] / final_table['TotalSalesDollars'])*100

# %%
final_table['StockTurnover'] = final_table['TotalSalesQuantity'] / final_table['TotalPurchaseQuantity']

# %%
final_table['SalesPurchaseRatio'] = final_table['TotalSalesDollars'] / final_table['TotalPurchaseDollars']

# %%
final_table.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'ActualPrice',
#        'PurchasePrice', 'Volume', 'TotalSalesQuantity', 'TotalSalesDollars',
#        'TotalSalesPrice', 'TotalExciseTax', 'TotalPurchaseQuantity',
#        'TotalPurchaseDollars', 'TotalFreightCost', 'GrossProfit',
#        'ProfitMargin', 'StockTurnover', 'SalesPurchaseRatio'],
#       dtype='object')

# %%
#used to establish connection with db
con = engine.connect()

# %%
from sqlalchemy import text
con.execute(text("""CREATE TABLE final_table (
    VendorNumber INT,            
    VendorName VARCHAR(100),               
    Brand INT,
    Description VARCHAR(100),              
    ActualPrice DECIMAL(10,2),             
    PurchasePrice DECIMAL(10,2),           
    Volume INT ,                  
    TotalSalesQuantity INT,      
    TotalSalesDollars DECIMAL(15,2),       
    TotalSalesPrice DECIMAL(15,2),         
    TotalExciseTax DECIMAL(15,2),          
    TotalPurchaseQuantity INT,  
    TotalPurchaseDollars DECIMAL(15,2),    
    TotalFreightCost DECIMAL(15,2),   
    GrossProfit DECIMAL(15,2),
    ProfitMargin DECIMAL(15,2),
    StockTurnover DECIMAL(15,2),
    SalesPurchaseRatio DECIMAL(15,2),
    PRIMARY KEY (VendorNumber, Brand)
    );
    """))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1202 try:
# -> 1203     first_packet = self.connection._read_packet()
#    1205     if first_packet.is_ok_packet():
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (1050, "Table 'final_table' already exists")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[126], line 2
#       1 from sqlalchemy import text
# ----> 2 con.execute(text("""CREATE TABLE final_table (
#       3     VendorNumber INT,
#       4     VendorName VARCHAR(100),
#       5     Brand INT,
#       6     Description VARCHAR(100),
#       7     ActualPrice DECIMAL(10,2),
#       8     PurchasePrice DECIMAL(10,2),
#       9     Volume INT ,
#      10     TotalSalesQuantity INT,
#      11     TotalSalesDollars DECIMAL(15,2),
#      12     TotalSalesPrice DECIMAL(15,2),
#      13     TotalExciseTax DECIMAL(15,2),
#      14     TotalPurchaseQuantity INT,
#      15     TotalPurchaseDollars DECIMAL(15,2),
#      16     TotalFreightCost DECIMAL(15,2),
#      17     GrossProfit DECIMAL(15,2),
#      18     ProfitMargin DECIMAL(15,2),
#      19     StockTurnover DECIMAL(15,2),
#      20     SalesPurchaseRatio DECIMAL(15,2),
#      21     PRIMARY KEY (VendorNumber, Brand)
#      22     );
#      23     """))
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)
#    1657         ret,
#    1658     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:575, in Connection.query(self, sql, unbuffered)
#     573     sql = sql.encode(self.encoding, "surrogateescape")
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:826, in Connection._read_query_result(self, unbuffered)
#     824     result.init_unbuffered_query()
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#     828 if result.server_status is not None:
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:1203, in MySQLResult.read(self)
#    1201 def read(self):
#    1202     try:
# -> 1203         first_packet = self.connection._read_packet()
#    1205         if first_packet.is_ok_packet():
#    1206             self._read_ok_packet(first_packet)
#
# File ~\anaconda3\Lib\site-packages\pymysql\connections.py:782, in Connection._read_packet(self, packet_type)
#     780     if self._result is not None and self._result.unbuffered_active is True:
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File ~\anaconda3\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~\anaconda3\Lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1050, "Table 'final_table' already exists")
# [SQL: CREATE TABLE final_table (
#     VendorNumber INT,
#     VendorName VARCHAR(100),
#     Brand INT,
#     Description VARCHAR(100),
#     ActualPrice DECIMAL(10,2),
#     PurchasePrice DECIMAL(10,2),
#     Volume INT ,
#     TotalSalesQuantity INT,
#     TotalSalesDollars DECIMAL(15,2),
#     TotalSalesPrice DECIMAL(15,2),
#     TotalExciseTax DECIMAL(15,2),
#     TotalPurchaseQuantity INT,
#     TotalPurchaseDollars DECIMAL(15,2),
#     TotalFreightCost DECIMAL(15,2),
#     GrossProfit DECIMAL(15,2),
#     ProfitMargin DECIMAL(15,2),
#     StockTurnover DECIMAL(15,2),
#     SalesPurchaseRatio DECIMAL(15,2),
#     PRIMARY KEY (VendorNumber, Brand)
#     );
#     ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
pd.read_sql_query("select *from final_table",con=engine )
# Out:
#     VendorNumber                   VendorName  Brand  \
# 0           9552               M S WALKER INC   1094
# 1           8112        MOET HENNESSY USA INC   1133
# 2           8352                    LUXCO INC   1135
# 3           8112        MOET HENNESSY USA INC    115
# 4           8352                    LUXCO INC   1174
# 5           3924     HEAVEN HILL DISTILLERIES   1178
# 6           3924     HEAVEN HILL DISTILLERIES   1180
# 7           3924     HEAVEN HILL DISTILLERIES   1186
# 8           2555  DISARONNO INTERNATIONAL LLC   1212
# 9           1128            BROWN-FORMAN CORP   1220
# 10          9625  WESTERN SPIRITS BEVERAGE CO   1226
# 11          3664     WILLIAM GRANT & SONS INC   1228
# 12          1128            BROWN-FORMAN CORP   1231
# 13          1128            BROWN-FORMAN CORP   1232
# 14          1128            BROWN-FORMAN CORP   1233
# 15          1128            BROWN-FORMAN CORP   1237
# 16         17035            PERNOD RICARD USA   1238
# 17         12546      JIM BEAM BRANDS COMPANY   1239
# 18          1128            BROWN-FORMAN CORP   1244
# 19         12546      JIM BEAM BRANDS COMPANY   1258
# 20           480              BACARDI USA INC    126
# 21          1485          CASTLE BRANDS CORP.   1269
# 22          1485          CASTLE BRANDS CORP.   1271
# 23         12546      JIM BEAM BRANDS COMPANY   1273
# 24         12546      JIM BEAM BRANDS COMPANY   1278
# 25          8004               SAZERAC CO INC   1281
# 26           660   SAZERAC NORTH AMERICA INC.   1282
# 27          1128            BROWN-FORMAN CORP   1295
# 28         12546      JIM BEAM BRANDS COMPANY   1309
# 29          1128            BROWN-FORMAN CORP   1323
# 30         12546      JIM BEAM BRANDS COMPANY   1340
# 31         12546      JIM BEAM BRANDS COMPANY   1345
# 32         12546      JIM BEAM BRANDS COMPANY   1346
# 33         12546      JIM BEAM BRANDS COMPANY   1347
# 34         12546      JIM BEAM BRANDS COMPANY   1348
# 35         12546      JIM BEAM BRANDS COMPANY   1355
# 36         12546      JIM BEAM BRANDS COMPANY   1358
# 37         12546      JIM BEAM BRANDS COMPANY   1359
# 38          6213                      MHW LTD   1364
# 39          8664        STOLI GROUP,(USA) LLC   1365
# 40         12546      JIM BEAM BRANDS COMPANY   1366
# 41         12546      JIM BEAM BRANDS COMPANY   1373
# 42         12546      JIM BEAM BRANDS COMPANY   1375
# 43         12546      JIM BEAM BRANDS COMPANY   1376
# 44         12546      JIM BEAM BRANDS COMPANY   1378
# 45         12546      JIM BEAM BRANDS COMPANY   1379
# 46          3960     DIAGEO NORTH AMERICA INC   1380
# 47         12546      JIM BEAM BRANDS COMPANY   1382
# 48          3960     DIAGEO NORTH AMERICA INC   1384
# 49         12546      JIM BEAM BRANDS COMPANY   1385
# 50          3960     DIAGEO NORTH AMERICA INC   1386
# 51         12546      JIM BEAM BRANDS COMPANY   1388
# 52         12546      JIM BEAM BRANDS COMPANY   1389
# 53         12546      JIM BEAM BRANDS COMPANY   1392
# 54         12546      JIM BEAM BRANDS COMPANY   1394
# 55         12546      JIM BEAM BRANDS COMPANY   1395
# 56         12546      JIM BEAM BRANDS COMPANY   1396
#
#                      Description  ActualPrice  PurchasePrice  Volume  \
# 0   Four Roses Single Barrel Brb        40.99          29.92     750
# 1   Glenmorangie Collection 4 Pk        31.99          23.01     100
# 2          Rebel Reserve Bourbon        19.99          15.62     750
# 3                Belvedere Vodka        27.99          21.37    1000
# 4                     Rebel Yell        19.99          15.87    1750
# 5    Evan Williams Black Label B        10.99           7.83     750
# 6    Evan Williams Black Label B        16.99          13.07    1750
# 7    Evan Williams Single Barrel        24.99          17.98     750
# 8    DiSaronna Amaretto Sour VAP        21.99          14.38     750
# 9       Woodford Reserve Bourbon        29.99          21.89     750
# 10             Lexington Bourbon        29.99          19.99     750
# 11    Glenfiddich Ancient RSV 18        95.99          69.76     750
# 12       Jack Daniels No 7 Black        12.99           9.48     375
# 27 -5.617259e+07 -1.777569e+06       0.000177            0.000056
# 28 -4.434746e+06 -6.160397e+05       0.000022            0.000162
# 29 -2.930530e+07 -7.732106e+05       0.000082            0.000129
# 30 -8.870501e+06 -2.054498e+06       0.000022            0.000049
# 31 -2.660859e+07 -6.318948e+05       0.000033            0.000158
# 32 -6.208465e+07 -5.227723e+05       0.000052            0.000191
# 33 -8.869973e+06 -9.241865e+05       0.000022            0.000108
# 34 -7.096305e+07 -1.607958e+06       0.000032            0.000062
# 35 -2.661209e+07 -3.737862e+06       0.000063            0.000027
# 36 -2.217138e+07 -3.725631e+05       0.000035            0.000268
# 37 -4.435063e+07 -1.100359e+06       0.000027            0.000091
# 38 -3.380239e+05 -2.819686e+05       0.000254            0.000355
# 39 -6.480473e+06 -4.827815e+05       0.000398            0.000207
# 40 -8.427271e+07 -7.356721e+06       0.000086            0.000014
# 41 -5.765742e+07 -1.581614e+06       0.000036            0.000063
# 42 -7.096294e+07 -1.569671e+06       0.000036            0.000064
# 43 -1.019866e+08 -3.507676e+05       0.000102            0.000285
# 44 -1.020091e+08 -1.544413e+06       0.000056            0.000065
# 45 -9.313826e+07 -1.426409e+06       0.000039            0.000070
# 46 -3.151648e+07 -1.333455e+06       0.000013            0.000075
# 47 -2.217486e+07 -8.972590e+05       0.000022            0.000111
# 48 -1.103081e+08 -1.406094e+06       0.000022            0.000071
# 49 -8.869540e+07 -6.368666e+05       0.000048            0.000157
# 50 -7.879447e+06 -2.985996e+06       0.000013            0.000033
# 51 -1.330550e+07 -1.478980e+06       0.000022            0.000068
# 52 -2.217704e+07 -7.726116e+06       0.000035            0.000013
# 53 -8.870417e+06 -1.720273e+06       0.000033            0.000058
# 54 -2.217634e+07 -2.241393e+06       0.000022            0.000045
# 55 -5.322387e+07 -3.083940e+06       0.000033            0.000032
# 56 -4.435082e+07 -1.155692e+06       0.000044            0.000087

# %%
final_table.to_sql('final_table', con=engine, if_exists='replace', index=False)
# Out:
# 57

# %%
def clean_data(df):
    '''this function will clean the data(I did not use)'''
    # changing datatype to float
    final_table['Volume'] = final_table['Volume'].astype('float')
  

    # filling missing value with 0(I did not use)
    final_table.fillna(0,inplace = True)

    # removing spaces from categorial columns
    final_table['VendorName'] = final_table['VendorName'].str.strip()
    final_table['Description'] = final_table['Description'].str.strip()
    
    # to view after spaces
    final_table['VendorName'].unique()
    final_table['Description'].unique()

    # creating new columns for better analysis
    final_table['GrossProfit'] = final_table['TotalSalesDollars'] - final_table['TotalPurchaseDollars']
    final_table['ProfitMargin'] = (final_table['GrossProfit'] / final_table['TotalSalesDollars'])*100
    final_table['StockTurnover'] = final_table['TotalSalesQuantity'] / final_table['TotalPurchaseQuantity']
    final_table['SalesPurchaseRatio'] = final_table['TotalSalesDollars'] / final_table['TotalPurchaseDollars']

    return final_table

# %%
import logging
from ingestion_db import ingest_db
logging.basicConfig(
    filename="logs/get_final_table.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)
if __name__ == '__main__':
    con = engine.connect()

    logging.info('Creating Vendor Summary Table......')
    summary_final_table = create_final_summary(con)
    logging.info(summary_final_table.head())

    logging.info('Cleaning Data......')
    clean_final_table = clean_data(summary_final_table)
    logging.info(clean_final_table.head())

    logging.info('Ingesting data......')
    ingest_db(clean_final_table,'vendor_final_summary',con)
    logging.info('Completed')

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
from ingestion_db import ingest_db
import time

'''Setup logging'''
logging.basicConfig(
    filename="logs/get_final_table.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

def create_final_summary(con=engine):
    start = time.time()
    '''this function will merge different tables to get the overall vendor summary & adding new columns in the data'''
    final_table = pd.read_sql_query("""SELECT
        pp.VendorNumber,
        pp.VendorName,
        pp.Brand,
        pp.Description,
        pp.Price AS ActualPrice,
        pp.PurchasePrice,
        pp.Volume ,
        SUM(s.SalesQuantity) AS TotalSalesQuantity,
        SUM(s.SalesDollars) AS TotalSalesDollars,
        SUM(s.SalesPrice) AS TotalSalesPrice,
        SUM(s.ExciseTax) AS TotalExciseTax,
        SUM(vi.Quantity) AS TotalPurchaseQuantity,
        SUM(vi.Dollars) AS TotalPurchaseDollars,
        SUM(vi.Freight) AS TotalFreightCost
        FROM purchase_prices1 pp
        JOIN sales1 s
        ON pp.VendorNumber = s.VendorNO
        AND pp.Brand = s.Brand
        JOIN vendor_invoice1 vi
        ON pp.VendorNumber = vi.VendorNumber
        GROUP BY pp.VendorNumber,
        pp.VendorName,
        pp.Brand,
        pp.Description,
        pp.Price,
        pp.PurchasePrice,
        pp.Volume 
        """, con=engine)
    end = time.time()
    print(f"Query executed in {end - start:.2f} seconds.")

    return final_table


def clean_data(df):
    '''this function will clean the data'''
    # changing datatype to float(I did not use)
    final_table['Volume'] = final_table['Volume'].astype('float')
  

    # filling missing value with 0(I did not use)
    final_table.fillna(0,inplace = True)

    # removing spaces from categorial columns
    final_table['VendorName'] = final_table['VendorName'].str.strip()
    final_table['Description'] = final_table['Description'].str.strip()
    
    # to view after spaces
    final_table['VendorName'].unique()
    final_table['Description'].unique()

    # creating new columns for better analysis
    final_table['GrossProfit'] = final_table['TotalSalesDollars'] - final_table['TotalPurchaseDollars']
    final_table['ProfitMargin'] = (final_table['GrossProfit'] / final_table['TotalSalesDollars'])*100
    final_table['StockTurnover'] = final_table['TotalSalesQuantity'] / final_table['TotalPurchaseQuantity']
    final_table['SalesPurchaseRatio'] = final_table['TotalSalesDollars'] / final_table['TotalPurchaseDollars']

    return final_table


if __name__ == '__main__':
    # creating database connection
    con = engine.connect()

    logging.info('Creating Vendor Summary Table......')
    summary_final_table = create_final_summary(con)
    logging.info(summary_final_table.head())

    logging.info('Cleaning Data......')
    clean_final_table = clean_data(summary_final_table)
    logging.info(clean_final_table.head())

    logging.info('Ingesting data......')
    ingest_db(clean_final_table,'vendor_final_summary',con)
    logging.info('Completed')
# Out:
# Query executed in 0.37 seconds.
